# %% [markdown]
# # 01 — Exploratory Data Analysis
#
# 탐색적 데이터 분석 노트북.
#
# ## 목적
# - (TODO) 데이터 분포 확인
# - (TODO) 결측치/이상치 점검
# - (TODO) 라벨 분포
#
# ## 메모
# - 출력은 commit 시 자동 정리됨 (nbstripout)

# %%
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# 프로젝트 루트 경로
ROOT = Path.cwd().parent
DATA = ROOT / "data"

# %%
# TODO: 데이터 로드
# df = pd.read_csv(DATA / "raw" / "...")
