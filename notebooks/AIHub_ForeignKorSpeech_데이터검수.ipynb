# %%
import json
from pathlib import Path
from IPython.display import Audio, display

DATASET_ROOT = Path("/data/ASR/BENCHMARK/GOLD/AIHub_ForeignKorSpeech")

index = {}
with open(DATASET_ROOT / "transcript.jsonl") as f:
    for line in f:
        if line.strip():
            r = json.loads(line)
            index[r["key"]] = r
print(f"transcript {len(index)}건 로드")

# %%
TARGET_KEYS = """
AIHub_ForeignKorSpeech__047943
AIHub_ForeignKorSpeech__043416
AIHub_ForeignKorSpeech__020719
AIHub_ForeignKorSpeech__058028
AIHub_ForeignKorSpeech__007492
AIHub_ForeignKorSpeech__047526
AIHub_ForeignKorSpeech__073249
AIHub_ForeignKorSpeech__073989
AIHub_ForeignKorSpeech__072260
AIHub_ForeignKorSpeech__047819
AIHub_ForeignKorSpeech__002733
AIHub_ForeignKorSpeech__053008
AIHub_ForeignKorSpeech__024551
AIHub_ForeignKorSpeech__013447
AIHub_ForeignKorSpeech__051964
AIHub_ForeignKorSpeech__047920
AIHub_ForeignKorSpeech__065410
AIHub_ForeignKorSpeech__003248
AIHub_ForeignKorSpeech__108034
AIHub_ForeignKorSpeech__081167
AIHub_ForeignKorSpeech__065323
AIHub_ForeignKorSpeech__011300
AIHub_ForeignKorSpeech__073783
AIHub_ForeignKorSpeech__043480
AIHub_ForeignKorSpeech__051996
AIHub_ForeignKorSpeech__001061
AIHub_ForeignKorSpeech__039618
AIHub_ForeignKorSpeech__066237
AIHub_ForeignKorSpeech__098567
AIHub_ForeignKorSpeech__054460
AIHub_ForeignKorSpeech__094692
AIHub_ForeignKorSpeech__105788
AIHub_ForeignKorSpeech__020632
AIHub_ForeignKorSpeech__113331
AIHub_ForeignKorSpeech__018465
AIHub_ForeignKorSpeech__104432
AIHub_ForeignKorSpeech__037072
AIHub_ForeignKorSpeech__015389
AIHub_ForeignKorSpeech__058756
AIHub_ForeignKorSpeech__073975
AIHub_ForeignKorSpeech__073259
AIHub_ForeignKorSpeech__041015
AIHub_ForeignKorSpeech__002719
AIHub_ForeignKorSpeech__073516
AIHub_ForeignKorSpeech__073133
AIHub_ForeignKorSpeech__024561
AIHub_ForeignKorSpeech__010384
AIHub_ForeignKorSpeech__024123
AIHub_ForeignKorSpeech__002552
AIHub_ForeignKorSpeech__073519
AIHub_ForeignKorSpeech__046789
AIHub_ForeignKorSpeech__005482
AIHub_ForeignKorSpeech__047453
AIHub_ForeignKorSpeech__073339
AIHub_ForeignKorSpeech__013396
AIHub_ForeignKorSpeech__093502
AIHub_ForeignKorSpeech__075456
AIHub_ForeignKorSpeech__047467
AIHub_ForeignKorSpeech__047696
AIHub_ForeignKorSpeech__036434
AIHub_ForeignKorSpeech__013133
AIHub_ForeignKorSpeech__023652
AIHub_ForeignKorSpeech__073242
AIHub_ForeignKorSpeech__064304
AIHub_ForeignKorSpeech__073664
AIHub_ForeignKorSpeech__081416
AIHub_ForeignKorSpeech__073579
AIHub_ForeignKorSpeech__002979
AIHub_ForeignKorSpeech__023508
AIHub_ForeignKorSpeech__107071
AIHub_ForeignKorSpeech__084259
AIHub_ForeignKorSpeech__046105
AIHub_ForeignKorSpeech__108620
AIHub_ForeignKorSpeech__112998
AIHub_ForeignKorSpeech__107919
AIHub_ForeignKorSpeech__068321
AIHub_ForeignKorSpeech__076434
AIHub_ForeignKorSpeech__020635
AIHub_ForeignKorSpeech__058446
AIHub_ForeignKorSpeech__075481
AIHub_ForeignKorSpeech__080698
AIHub_ForeignKorSpeech__080560
AIHub_ForeignKorSpeech__075574
AIHub_ForeignKorSpeech__112537
AIHub_ForeignKorSpeech__100160
AIHub_ForeignKorSpeech__078238
AIHub_ForeignKorSpeech__090957
AIHub_ForeignKorSpeech__031963
AIHub_ForeignKorSpeech__059988
AIHub_ForeignKorSpeech__081857
AIHub_ForeignKorSpeech__083238
AIHub_ForeignKorSpeech__082203
AIHub_ForeignKorSpeech__032321
AIHub_ForeignKorSpeech__065517
AIHub_ForeignKorSpeech__100727
AIHub_ForeignKorSpeech__001220
AIHub_ForeignKorSpeech__077110
AIHub_ForeignKorSpeech__105110
AIHub_ForeignKorSpeech__058838
AIHub_ForeignKorSpeech__044140
AIHub_ForeignKorSpeech__014089
AIHub_ForeignKorSpeech__036208
AIHub_ForeignKorSpeech__033466
AIHub_ForeignKorSpeech__029949
AIHub_ForeignKorSpeech__035818
AIHub_ForeignKorSpeech__042415
AIHub_ForeignKorSpeech__041588
AIHub_ForeignKorSpeech__018191
AIHub_ForeignKorSpeech__028683
AIHub_ForeignKorSpeech__093603
AIHub_ForeignKorSpeech__112824
AIHub_ForeignKorSpeech__111355
AIHub_ForeignKorSpeech__024906
AIHub_ForeignKorSpeech__046019
AIHub_ForeignKorSpeech__096851
AIHub_ForeignKorSpeech__113725
AIHub_ForeignKorSpeech__046898
AIHub_ForeignKorSpeech__033681
AIHub_ForeignKorSpeech__010082
AIHub_ForeignKorSpeech__032742
AIHub_ForeignKorSpeech__111449
AIHub_ForeignKorSpeech__087528
""".split()

TARGET_KEYS = list(dict.fromkeys(TARGET_KEYS))
print(f"대상 키: {len(TARGET_KEYS)}개")

# %%
playlist, missing_tsv, missing_wav = [], [], []
for k in TARGET_KEYS:
    row = index.get(k)
    if row is None:
        missing_tsv.append(k); continue
    wav = DATASET_ROOT / row["audio"]
    if not wav.exists():
        missing_wav.append(k); continue
    playlist.append((k, row, wav))

print(f"재생 가능 {len(playlist)} | transcript에 없음 {len(missing_tsv)} | wav 없음 {len(missing_wav)}")
if missing_tsv: print("  없는 key:", missing_tsv[:10])
if missing_wav: print("  wav 누락:", missing_wav[:10])

# ⚠️ 한 번에 다 띄우면 무거움 — playlist[:30] 식으로 끊어 권장
for i, (k, row, wav) in enumerate(playlist, 1):
    age  = row.get("age") or "-"
    gen  = row.get("gender") or "-"
    mask = "마스크" if row.get("has_mask") else ""
    star = "  ★star_fixed" if row.get("star_fixed") else ""
    print(f"[{i}/{len(playlist)}] {k}  |  {row['duration']}s  {age} {gen} {mask}{star}")
    print(f"  text      : {row['text']}")
    print(f"  text_norm : {row['text_norm']}")
    display(Audio(str(wav)))
    print("-" * 80)
